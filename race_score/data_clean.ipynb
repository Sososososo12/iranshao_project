# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel(r'../comment_resource/all_comments_dupli.xlsx')

# %%
data
# Out:
#                                          comment_contents  comment_race_id  \
# 0       \n      第7次上马，怀有特殊的感情。今年可能是受到进博会的影响，赛前氛围没有去年大气...              583
# 1       \n      这次本来是陪着男朋友去跑上马的，机票酒店早就定好了，后面在爱燃烧的微博上看到...              583
# 2       \n      赛道平坦，开始前几公里都没问题，问题是到了步行街位置，雨天路滑，稍有不慎都会...              583
# 3       \n      0-10公里/变速跑：赞助商名额全部分在最后一个区出发，慢慢走到起点已经过了...              583
# 4       \n      说说需要改进的地方吧，上马起跑分区明明分的很细，但是因为提前把后面分区的人放...              583
# 5       \n      有一种快叫上马，虽然没能在上马PB，但SB也很让我欣慰。赛前赛后的短信提示很...              583
# 6       \n      上马组织和氛围还是非常到位的，但还是有一些瑕疵：厕所一如既往不够用；开赛前过...              583
# 7       \n      嗯，跑过终点看到大屏幕的滚动的字鼻子一酸。一年一次的上马，带着两脚的各种伤痛...              583
# 8                                   \n      上马年年参加的\n                  583
# 9                                \n      很好的比赛,年年参加\n                  583
# 10             \n      出发时堵塞严重，线路转弯较多，后期补给不足，但仍然难忘。\n                  583
# ...

# %%
datadf=pd.DataFrame(data)

# %%
datadf
# Out:
#                                          comment_contents  comment_race_id  \
# 0       \n      第7次上马，怀有特殊的感情。今年可能是受到进博会的影响，赛前氛围没有去年大气...              583
# 1       \n      这次本来是陪着男朋友去跑上马的，机票酒店早就定好了，后面在爱燃烧的微博上看到...              583
# 2       \n      赛道平坦，开始前几公里都没问题，问题是到了步行街位置，雨天路滑，稍有不慎都会...              583
# 3       \n      0-10公里/变速跑：赞助商名额全部分在最后一个区出发，慢慢走到起点已经过了...              583
# 4       \n      说说需要改进的地方吧，上马起跑分区明明分的很细，但是因为提前把后面分区的人放...              583
# 5       \n      有一种快叫上马，虽然没能在上马PB，但SB也很让我欣慰。赛前赛后的短信提示很...              583
# 6       \n      上马组织和氛围还是非常到位的，但还是有一些瑕疵：厕所一如既往不够用；开赛前过...              583
# 7       \n      嗯，跑过终点看到大屏幕的滚动的字鼻子一酸。一年一次的上马，带着两脚的各种伤痛...              583
# 8                                   \n      上马年年参加的\n                  583
# 9                                \n      很好的比赛,年年参加\n                  583
# 10             \n      出发时堵塞严重，线路转弯较多，后期补给不足，但仍然难忘。\n                  583
# ...

# %%
type(datadf)
# Out:
# pandas.core.frame.DataFrame

# %%
datadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123829 entries, 0 to 123828
# Data columns (total 12 columns):
# comment_contents            123829 non-null object
# comment_race_id             123829 non-null int64
# comment_score_atomsphere    62807 non-null float64
# comment_score_mean          120710 non-null float64
# comment_score_organize      120257 non-null float64
# comment_score_sight         120710 non-null float64
# comment_times               123829 non-null object
# comment_tp_event            115574 non-null object
# comment_tp_finishedtime     108406 non-null object
# comment_tp_ytime            123829 non-null int64
# comment_user_id             123829 non-null object
# comment_user_name           123828 non-null object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 11.3+ MB
